# %% [markdown]
# <a href="https://colab.research.google.com/github/henry-del/assignment2/blob/master/%E6%9C%9F%E6%9C%AB%E4%BD%9C%E6%A5%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd '/content/gdrive/MyDrive/'
# !ls
# Out:
# /content/gdrive/MyDrive
#  ANCOVA.gslides
# 'BMS109106 林昌璟.docx'
# 'BMS109106 林昌璟.gdoc'
#  Ch05.gdoc
#  Classroom
# 'Colab Notebooks'
# 'Untitled Diagram.drawio'
#  xAPI-Edu-Data.csv
# '作業_林昌璟 (1).rtf.gdoc'
# '作業_林昌璟 (2).rtf.gdoc'
#  作業_林昌璟.rtf
#  作業_林昌璟.rtf.gdoc
# '創造性思維命題卡(空白) (1).gdoc'
# '創造性思維命題卡(空白).gdoc'
# '創造性思維命題卡(舊鞋救命科學問題解決)_20210318 (1).gdoc'
# '創造性思維命題卡(舊鞋救命科學問題解決)_20210318.gdoc'
# '康0905五01 (1).gsheet'
# '康0905五01 (2).gsheet'
# '康0905五01 (3).gsheet'
#  康0905五01.gsheet
#  教師評語_text
#  文獻評析作業.gdoc
# '期末報告 林昌璟 (1).gdoc'
# '期末報告 林昌璟 (2).gdoc'
# '期末報告 林昌璟.docx'
# '期末報告 林昌璟.gdoc'
#  未命名文件.gdoc
#  研究方法_信度與效度20210426.gdoc
# '統計期中報告_林昌璟 (1).docx'
# '統計期中報告_林昌璟 (1).gdoc'
# '統計期中報告_林昌璟 (2).docx'
# '統計期中報告_林昌璟 (2).gdoc'
# '統計期中報告_林昌璟 (3).docx'
# '統計期中報告_林昌璟 (3).gdoc'
# '統計期中報告_林昌璟 (4).gdoc'
#  統計期中報告_林昌璟.docx
#  統計期中報告_林昌璟.gdoc
#  舊鞋救命寫作表達題目.gdoc
#  視覺題
#  訓練模型資料

# %%
data=pd.read_csv("xAPI-Edu-Data.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    480 non-null    object
#  1   NationalITy               480 non-null    object
#  2   PlaceofBirth              480 non-null    object
#  3   StageID                   480 non-null    object
#  4   GradeID                   480 non-null    object
#  5   SectionID                 480 non-null    object
#  6   Topic                     480 non-null    object
#  7   Semester                  480 non-null    object
#  8   Relation                  480 non-null    object
#  9   raisedhands               480 non-null    int64
#  10  VisITedResources          480 non-null    int64
#  11  AnnouncementsView         480 non-null    int64
#  12  Discussion                480 non-null    int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
data.rename(index=str, columns={'gender':'Gender', 'NationalITy':'Nationality',
                               'raisedhands':'RaisedHands', 'VisITedResources':'VisitedResources'},
                               inplace=True)

# %%
str_columns = data.dtypes[data.dtypes == 'object'].index
for col in str_columns:
    data[col] = LabelEncoder().fit_transform(data[col])

# %%
data = pd.get_dummies(data, columns=str_columns.drop(['Class', 'StageID']))
data.shape
# Out:
# (480, 71)

# %%
data
# Out:
#      StageID  RaisedHands  ...  StudentAbsenceDays_0  StudentAbsenceDays_1
# 0          2           15  ...                     0                     1
# 1          2           20  ...                     0                     1
# 2          2           10  ...                     1                     0
# 3          2           30  ...                     1                     0
# 4          2           40  ...                     1                     0
# ..       ...          ...  ...                   ...                   ...
# 475        1            5  ...                     1                     0
# 476        1           50  ...                     0                     1
# 477        1           55  ...                     0                     1
# 478        1           30  ...                     1                     0
# 479        1           35  ...                     1                     0
#
# [480 rows x 71 columns]

# %%
x = data.drop(['Class'], axis=1)
y = data['Class']

# %%
x
# Out:
#      StageID  RaisedHands  ...  StudentAbsenceDays_0  StudentAbsenceDays_1
# 0          2           15  ...                     0                     1
# 1          2           20  ...                     0                     1
# 2          2           10  ...                     1                     0
# 3          2           30  ...                     1                     0
# 4          2           40  ...                     1                     0
# ..       ...          ...  ...                   ...                   ...
# 475        1            5  ...                     1                     0
# 476        1           50  ...                     0                     1
# 477        1           55  ...                     0                     1
# 478        1           30  ...                     1                     0
# 479        1           35  ...                     1                     0
#
# [480 rows x 70 columns]

# %%
y
# Out:
# 0      2
# 1      2
# 2      1
# 3      1
# 4      2
#       ..
# 475    1
# 476    2
# 477    2
# 478    1
# 479    1
# Name: Class, Length: 480, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

y = labelencoder.fit_transform(y)

# %%
y
# Out:
# array([2, 2, 1, 1, 2, 2, 1, 2, 2, 2, 0, 2, 1, 1, 0, 2, 2, 2, 2, 0, 2, 2,
#        2, 1, 1, 1, 2, 1, 2, 2, 0, 1, 1, 1, 1, 1, 1, 2, 1, 2, 1, 2, 1, 2,
#        2, 1, 1, 0, 0, 2, 1, 1, 2, 0, 1, 1, 1, 1, 2, 2, 1, 2, 0, 2, 1, 1,
#        2, 0, 0, 2, 1, 2, 1, 2, 1, 2, 2, 2, 1, 0, 1, 1, 1, 2, 0, 1, 0, 1,
#        1, 1, 1, 0, 0, 0, 1, 0, 0, 2, 2, 2, 2, 0, 1, 1, 2, 1, 2, 0, 2, 2,
#        0, 2, 1, 1, 1, 1, 2, 0, 2, 2, 2, 1, 2, 2, 1, 1, 2, 1, 1, 1, 1, 2,
#        1, 1, 0, 0, 0, 2, 0, 2, 1, 1, 2, 0, 1, 2, 0, 2, 2, 0, 0, 2, 0, 1,
#        2, 0, 2, 2, 1, 2, 0, 2, 0, 2, 2, 0, 2, 0, 0, 2, 0, 2, 1, 1, 2, 1,
#        0, 2, 0, 2, 0, 1, 0, 2, 1, 0, 2, 2, 0, 2, 1, 1, 2, 2, 2, 2, 0, 0,
#        1, 2, 0, 0, 2, 2, 1, 0, 2, 2, 2, 2, 0, 2, 0, 1, 1, 1, 2, 2, 0, 2,
#        2, 2, 2, 0, 0, 2, 1, 1, 0, 1, 2, 1, 2, 2, 2, 1, 1, 2, 2, 0, 0, 2,
#        1, 2, 0, 2, 0, 2, 1, 2, 0, 1, 2, 1, 0, 0, 0, 2, 2, 1, 1, 2, 2, 2,
#        2, 0, 2, 2, 2, 2, 0, 2, 2, 0, 0, 0, 0, 0, 2, 2, 0, 0, 0, 0, 2, 2,
# ...

# %%
from sklearn.model_selection import train_test_split
import numpy as np

# %%
X_train,X_test, y_train, y_test = train_test_split(x, y,test_size=0.2, random_state=10,shuffle=True )

# %%
X_train
# Out:
#      StageID  RaisedHands  ...  StudentAbsenceDays_0  StudentAbsenceDays_1
# 319        2           50  ...                     0                     1
# 214        1           17  ...                     1                     0
# 433        1           87  ...                     0                     1
# 469        1            9  ...                     1                     0
# 299        2           32  ...                     1                     0
# ..       ...          ...  ...                   ...                   ...
# 369        2           75  ...                     0                     1
# 320        2           60  ...                     1                     0
# 15         1           30  ...                     0                     1
# 125        2           12  ...                     1                     0
# 265        1           79  ...                     0                     1
#
# [384 rows x 70 columns]

# %%
# !pip show tensorflow
# Out:
# Name: tensorflow
# Version: 2.5.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /usr/local/lib/python3.7/dist-packages
# Requires: protobuf, termcolor, absl-py, astunparse, tensorflow-estimator, keras-preprocessing, numpy, six, wrapt, tensorboard, gast, flatbuffers, wheel, h5py, google-pasta, grpcio, opt-einsum, typing-extensions, keras-nightly
# Required-by: kapre

# %%
# !pip install -q keras

# %%
import sklearn

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import StratifiedKFold
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
 
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier

# %%
keys = []
scores = []
models = {'KNN': KNeighborsClassifier(),
          '邏輯迴歸': LogisticRegression(),
          '貝氏分類': GaussianNB(),
          '決策樹':DecisionTreeClassifier(),
          '支援向量機': SVC()}
 
for k,v in models.items():
    mod = v
    mod.fit(X_train, y_train)
    pred = mod.predict(X_test)
    acc = accuracy_score(y_test, pred)
    #print('accuracy：'+ str(acc)) 
    keys.append(k)
    scores.append(acc)
    table = pd.DataFrame({'model':keys, 'accuracy score':scores})
 
table
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
#    model  accuracy score
# 0    KNN        0.593750
# 1   邏輯迴歸        0.770833
# 2   貝氏分類        0.552083
# 3    決策樹        0.635417
# 4  支援向量機        0.614583
